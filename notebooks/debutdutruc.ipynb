# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import networkx as nx
from collections import defaultdict
import matplotlib.pyplot as plt
import seaborn as sns

# %%
PATH = "../datasets/filtered-data/"

movies = pd.read_csv(f"{PATH}filtered_movies.csv")
actors = pd.read_csv(f"{PATH}actors_actresses.csv")
crew = pd.read_csv(f"{PATH}filtered_crew.csv")
ratings = pd.read_csv(f"{PATH}filtered_ratings.csv")

# %% [markdown]
# ## Netttoyer les donnees

# %%
print(actors.shape)

# Compter le nombre de films par acteur
actor_film_counts = actors['nconst'].value_counts()

# Filtrer les acteurs ayant joué dans plus de 1 film
actors = actors[actors['nconst'].isin(actor_film_counts[actor_film_counts > 10].index)]
print(actors.shape)
# Out:
# (416137, 4)
# (133834, 4)

# %%
# Nettoyage des données
movies = movies.dropna(subset=['genres'])
movies['genres'] = movies['genres'].apply(lambda x: x.split(','))
movies = movies[movies["numVotes"] >= 20000]
movies = movies[movies["startYear"] >= 2000]

# Merge des datasets
actors = actors.merge(movies[['tconst', 'primaryTitle', 'genres']], on='tconst')
print(actors.shape)
# Out:
# (26060, 6)

# %%
# Pré-calcul des listes d'acteurs pour chaque film
movie_to_actors = defaultdict(list)
for _, row in actors.iterrows():
    movie_to_actors[row['tconst']].append(row['nconst'])

# %% [markdown]
# ## Creation du graph de cooccurence

# %%
# Création des graphes de co-occurrence des acteurs par genre optimisée
def create_cooccurrence_graph(data):
    genre_graphs = defaultdict(nx.Graph)

    for _, row in data.iterrows():
        for genre in row['genres']:
            actor_list = movie_to_actors[row['tconst']]
            for i in range(len(actor_list)):
                for j in range(i + 1, len(actor_list)):
                    actor_i, actor_j = actor_list[i], actor_list[j]
                    if not genre_graphs[genre].has_edge(actor_i, actor_j):
                        genre_graphs[genre].add_edge(actor_i, actor_j, weight=0)
                    genre_graphs[genre][actor_i][actor_j]['weight'] += 1

    return genre_graphs

# Créer les graphes par genre
genre_graphs = create_cooccurrence_graph(movies)

# %% [markdown]
# ### Stats du graph

# %%
# Affichage des statistiques des graphes
for genre, graph in genre_graphs.items():
    print(f"Genre: {genre}")
    print(f"Nombre d'acteurs: {graph.number_of_nodes()}")
    print(f"Nombre d'arêtes: {graph.number_of_edges()}")
    print(f"Degré moyen: {np.mean(list(dict(graph.degree()).values()))}")
    print(f"Clustering moyen: {nx.average_clustering(graph)}")
    print()
# Out:
# Genre: Comedy
# Nombre d'acteurs: 2623
# Nombre d'arêtes: 23793
# Degré moyen: 18.14182234083111
# Clustering moyen: 0.5572520754906921
#
# Genre: Fantasy
# Nombre d'acteurs: 1294
# Nombre d'arêtes: 5272
# Degré moyen: 8.1483771251932
# Clustering moyen: 0.7866543523978902
#
# Genre: Romance
# Nombre d'acteurs: 1872
# Nombre d'arêtes: 9620
# Degré moyen: 10.277777777777779
# Clustering moyen: 0.6900524527900966
#
# Genre: Drama
# Nombre d'acteurs: 3320
# Nombre d'arêtes: 31799
# Degré moyen: 19.156024096385543
# Clustering moyen: 0.5078818880908088
#
# Genre: Music
# Nombre d'acteurs: 470
# Nombre d'arêtes: 1184
# Degré moyen: 5.038297872340426
# Clustering moyen: 0.8902653325273707
#
# Genre: Adventure
# Nombre d'acteurs: 2065
# Nombre d'arêtes: 15324
# Degré moyen: 14.841646489104116
# Clustering moyen: 0.6181004824700351
#
# Genre: Animation
# Nombre d'acteurs: 792
# Nombre d'arêtes: 3871
# Degré moyen: 9.775252525252526
# Clustering moyen: 0.7341616232944213
#
# Genre: Action
# Nombre d'acteurs: 2706
# Nombre d'arêtes: 22376
# Degré moyen: 16.538063562453807
# Clustering moyen: 0.5826568853747154
#
# Genre: Biography
# Nombre d'acteurs: 1186
# Nombre d'arêtes: 5129
# Degré moyen: 8.649241146711637
# Clustering moyen: 0.7433227875396126
#
# Genre: Horror
# Nombre d'acteurs: 1315
# Nombre d'arêtes: 4051
# Degré moyen: 6.1612167300380225
# Clustering moyen: 0.7245914946384518
#
# Genre: Mystery
# Nombre d'acteurs: 1568
# Nombre d'arêtes: 6729
# Degré moyen: 8.582908163265307
# Clustering moyen: 0.7156207439778012
#
# Genre: Thriller
# Nombre d'acteurs: 1934
# Nombre d'arêtes: 9979
# Degré moyen: 10.319544984488108
# Clustering moyen: 0.6888541070144248
#
# Genre: Sci-Fi
# Nombre d'acteurs: 1161
# Nombre d'arêtes: 5393
# Degré moyen: 9.290267011197244
# Clustering moyen: 0.7612343359116259
#
# Genre: Crime
# Nombre d'acteurs: 2344
# Nombre d'arêtes: 14466
# Degré moyen: 12.343003412969283
# Clustering moyen: 0.6474879881250782
#
# Genre: Family
# Nombre d'acteurs: 802
# Nombre d'arêtes: 3065
# Degré moyen: 7.643391521197008
# Clustering moyen: 0.8044940389013211
#
# Genre: Sport
# Nombre d'acteurs: 447
# Nombre d'arêtes: 1320
# Degré moyen: 5.906040268456376
# Clustering moyen: 0.8936919112097196
#
# Genre: War
# Nombre d'acteurs: 262
# Nombre d'arêtes: 731
# Degré moyen: 5.580152671755725
# Clustering moyen: 0.8922811796296305
#
# Genre: History
# Nombre d'acteurs: 630
# Nombre d'arêtes: 2316
# Degré moyen: 7.352380952380952
# Clustering moyen: 0.8408213315953443
#
# Genre: Musical
# Nombre d'acteurs: 205
# Nombre d'arêtes: 635
# Degré moyen: 6.195121951219512
# Clustering moyen: 0.9149032677659876
#
# Genre: Western
# Nombre d'acteurs: 102
# Nombre d'arêtes: 255
# Degré moyen: 5.0
# Clustering moyen: 0.9889511360099595
#
# Genre: Documentary
# Nombre d'acteurs: 9
# Nombre d'arêtes: 30
# Degré moyen: 6.666666666666667
# Clustering moyen: 0.7777777777777778

# %% [markdown]
# ### Plot le graph pour un genre

# %%
# Visualiser un graphe de co-occurrence
def plot_graph(graph, title):
    plt.figure(figsize=(12, 8))
    pos = nx.spring_layout(graph, k=0.15)
    weights = nx.get_edge_attributes(graph, 'weight').values()
    nx.draw(graph, pos, node_size=50, font_size=10, edge_color=weights, edge_cmap=plt.cm.viridis, width=2)
    plt.title(title)
    plt.show()

# Exemple de visualisation pour un genre
plot_graph(genre_graphs['History'], 'Co-occurrence Graph for History')

# %% [markdown]
# ## Calculer les mesures de centralite du graph

# %%
import time

# Fonction pour calculer les mesures de centralité
def compute_centrality_measures(graphs):
    centrality_measures = defaultdict(dict)
    for genre, graph in graphs.items():
        start_time = time.time()
        print(f"Calcul des mesures de centralité pour le genre {genre}")

        centrality_measures[genre]['degree'] = nx.degree_centrality(graph)
        degree_time = time.time()
        print(f"Degree centrality done in {degree_time - start_time:.2f} seconds")

        centrality_measures[genre]['closeness'] = nx.closeness_centrality(graph)
        closeness_time = time.time()
        print(f"Closeness centrality done in {closeness_time - degree_time:.2f} seconds")

        centrality_measures[genre]['betweenness'] = nx.betweenness_centrality(graph)
        betweenness_time = time.time()
        print(f"Betweenness centrality done in {betweenness_time - closeness_time:.2f} seconds")

        try:
            centrality_measures[genre]['eigenvector'] = nx.eigenvector_centrality(graph)
            eigenvector_time = time.time()
            print(f"Eigenvector centrality done in {eigenvector_time - betweenness_time:.2f} seconds")
        except nx.PowerIterationFailedConvergence:
            print(f"Eigenvector centrality did not converge for genre {genre}")

        centrality_measures[genre]['pagerank'] = nx.pagerank(graph)
        pagerank_time = time.time()
        print(f"Pagerank centrality done in {pagerank_time - eigenvector_time:.2f} seconds")

        total_time = time.time() - start_time
        print(f"Terminé pour le genre {genre} en {total_time:.2f} seconds")

        print()
        
    return centrality_measures

# Calcul des mesures de centralité
centrality_measures = compute_centrality_measures(genre_graphs)
# Out:
# Calcul des mesures de centralité pour le genre Comedy
# Degree centrality done in 0.00 seconds
# Closeness centrality done in 15.03 seconds
# Betweenness centrality done in 61.76 seconds
# Eigenvector centrality done in 0.18 seconds
# Pagerank centrality done in 0.06 seconds
# Terminé pour le genre Comedy en 77.03 seconds
#
# Calcul des mesures de centralité pour le genre Fantasy
# Degree centrality done in 0.00 seconds
# Closeness centrality done in 1.56 seconds
# Betweenness centrality done in 7.46 seconds
# Eigenvector centrality done in 0.23 seconds
# Pagerank centrality done in 0.03 seconds
# Terminé pour le genre Fantasy en 9.27 seconds
#
# Calcul des mesures de centralité pour le genre Romance
# Degree centrality done in 0.00 seconds
# Closeness centrality done in 5.17 seconds
# Betweenness centrality done in 23.41 seconds
# Eigenvector centrality done in 0.15 seconds
# Pagerank centrality done in 0.02 seconds
# Terminé pour le genre Romance en 28.76 seconds
#
# Calcul des mesures de centralité pour le genre Drama
# Degree centrality done in 0.00 seconds
# Closeness centrality done in 27.81 seconds
# Betweenness centrality done in 104.89 seconds
# Eigenvector centrality done in 0.33 seconds
# Pagerank centrality done in 0.09 seconds
# Terminé pour le genre Drama en 133.12 seconds
#
# Calcul des mesures de centralité pour le genre Music
# Degree centrality done in 0.00 seconds
# Closeness centrality done in 0.02 seconds
# Betweenness centrality done in 0.12 seconds
# Eigenvector centrality did not converge for genre Music
# Pagerank centrality done in 0.34 seconds
# Terminé pour le genre Music en 0.26 seconds
#
# Calcul des mesures de centralité pour le genre Adventure
# Degree centrality done in 0.00 seconds
# Closeness centrality done in 7.66 seconds
# Betweenness centrality done in 34.12 seconds
# Eigenvector centrality done in 0.20 seconds
# Pagerank centrality done in 0.04 seconds
# Terminé pour le genre Adventure en 42.02 seconds
#
# Calcul des mesures de centralité pour le genre Animation
# Degree centrality done in 0.00 seconds
# Closeness centrality done in 0.75 seconds
# Betweenness centrality done in 3.00 seconds
# Eigenvector centrality done in 0.06 seconds
# Pagerank centrality done in 0.01 seconds
# Terminé pour le genre Animation en 3.81 seconds
#
# Calcul des mesures de centralité pour le genre Action
# Degree centrality done in 0.00 seconds
# Closeness centrality done in 12.73 seconds
# Betweenness centrality done in 60.33 seconds
# Eigenvector centrality done in 0.22 seconds
# Pagerank centrality done in 0.34 seconds
# Terminé pour le genre Action en 73.62 seconds
#
# Calcul des mesures de centralité pour le genre Biography
# Degree centrality done in 0.00 seconds
# Closeness centrality done in 1.36 seconds
# Betweenness centrality done in 5.48 seconds
# Eigenvector centrality done in 0.12 seconds
# Pagerank centrality done in 0.01 seconds
# Terminé pour le genre Biography en 6.97 seconds
#
# Calcul des mesures de centralité pour le genre Horror
# Degree centrality done in 0.00 seconds
# Closeness centrality done in 1.34 seconds
# Betweenness centrality done in 5.95 seconds
# Eigenvector centrality done in 0.29 seconds
# Pagerank centrality done in 0.01 seconds
# Terminé pour le genre Horror en 7.59 seconds
#
# Calcul des mesures de centralité pour le genre Mystery
# Degree centrality done in 0.00 seconds
# Closeness centrality done in 2.45 seconds
# Betweenness centrality done in 11.68 seconds
# Eigenvector centrality done in 0.15 seconds
# Pagerank centrality done in 0.02 seconds
# Terminé pour le genre Mystery en 14.31 seconds
#
# Calcul des mesures de centralité pour le genre Thriller
# Degree centrality done in 0.00 seconds
# Closeness centrality done in 5.43 seconds
# Betweenness centrality done in 22.36 seconds
# Eigenvector centrality done in 0.26 seconds
# Pagerank centrality done in 0.05 seconds
# Terminé pour le genre Thriller en 28.11 seconds
#
# Calcul des mesures de centralité pour le genre Sci-Fi
# Degree centrality done in 0.00 seconds
# Closeness centrality done in 1.64 seconds
# Betweenness centrality done in 5.82 seconds
# Eigenvector centrality done in 0.14 seconds
# Pagerank centrality done in 0.01 seconds
# Terminé pour le genre Sci-Fi en 7.61 seconds
#
# Calcul des mesures de centralité pour le genre Crime
# Degree centrality done in 0.00 seconds
# Closeness centrality done in 9.34 seconds
# Betweenness centrality done in 46.01 seconds
# Eigenvector centrality done in 0.35 seconds
# Pagerank centrality done in 0.06 seconds
# Terminé pour le genre Crime en 55.77 seconds
#
# Calcul des mesures de centralité pour le genre Family
# Degree centrality done in 0.00 seconds
# Closeness centrality done in 1.04 seconds
# Betweenness centrality done in 3.24 seconds
# Eigenvector centrality done in 0.22 seconds
# Pagerank centrality done in 0.02 seconds
# Terminé pour le genre Family en 4.53 seconds
#
# Calcul des mesures de centralité pour le genre Sport
# Degree centrality done in 0.00 seconds
# Closeness centrality done in 0.08 seconds
# Betweenness centrality done in 0.36 seconds
# Eigenvector centrality done in 0.05 seconds
# Pagerank centrality done in 0.00 seconds
# Terminé pour le genre Sport en 0.49 seconds
#
# Calcul des mesures de centralité pour le genre War
# Degree centrality done in 0.00 seconds
# Closeness centrality done in 0.01 seconds
# Betweenness centrality done in 0.03 seconds
# Eigenvector centrality done in 0.03 seconds
# Pagerank centrality done in 0.00 seconds
# Terminé pour le genre War en 0.08 seconds
#
# Calcul des mesures de centralité pour le genre History
# Degree centrality done in 0.00 seconds
# Closeness centrality done in 0.37 seconds
# Betweenness centrality done in 2.05 seconds
# Eigenvector centrality done in 0.17 seconds
# Pagerank centrality done in 0.01 seconds
# Terminé pour le genre History en 2.61 seconds
#
# Calcul des mesures de centralité pour le genre Musical
# Degree centrality done in 0.00 seconds
# Closeness centrality done in 0.01 seconds
# Betweenness centrality done in 0.06 seconds
# Eigenvector centrality done in 0.03 seconds
# Pagerank centrality done in 0.01 seconds
# Terminé pour le genre Musical en 0.11 seconds
#
# Calcul des mesures de centralité pour le genre Western
# Degree centrality done in 0.00 seconds
# Closeness centrality done in 0.00 seconds
# Betweenness centrality done in 0.01 seconds
# Eigenvector centrality done in 0.03 seconds
# Pagerank centrality done in 0.01 seconds
# Terminé pour le genre Western en 0.04 seconds
#
# Calcul des mesures de centralité pour le genre Documentary
# Degree centrality done in 0.00 seconds
# Closeness centrality done in 0.00 seconds
# Betweenness centrality done in 0.00 seconds
# Eigenvector centrality done in 0.00 seconds
# Pagerank centrality done in 0.00 seconds
# Terminé pour le genre Documentary en 0.01 seconds

# %% [markdown]
# ## Acteurs les plus centraux par genre

# %%
def get_top_central_actors(centrality_measures, top_n=5):
    top_actors = defaultdict(dict)
    for genre, measures in centrality_measures.items():
        for centrality_type, centrality in measures.items():
            # Trier les acteurs par centralité décroissante et prendre les top_n
            sorted_actors = sorted(centrality.items(), key=lambda x: x[1], reverse=True)[:top_n]
            top_actors[genre][centrality_type] = sorted_actors
    return top_actors

# Obtenir les acteurs les plus centraux pour chaque genre
top_actors = get_top_central_actors(centrality_measures, top_n=3)

# Afficher les acteurs les plus centraux pour chaque genre
for genre, centralities in top_actors.items():
    print(f"Genre: {genre}")
    for centrality_type, actors in centralities.items():
        print(f"  {centrality_type} centrality:")
        for actor, value in actors:
            print(f"    Actor: {actor}, Centrality: {value:.4f}")
    print()

def plot_centrality_bars(top_actors, centrality_type='degree'):
    data = []
    for genre, centralities in top_actors.items():
        if centrality_type in centralities:
            for actor, value in centralities[centrality_type]:
                data.append([genre, actor, value])
    df = pd.DataFrame(data, columns=['Genre', 'Actor', 'Centrality'])

    # Créer des graphiques de barres pour chaque genre
    plt.figure(figsize=(15, 10))
    sns.barplot(x='Centrality', y='Actor', hue='Genre', data=df, dodge=False)
    plt.title(f'Top Actors by {centrality_type.capitalize()} Centrality')
    plt.xlabel('Centrality')
    plt.ylabel('Actor')
    plt.show()

# Exemple de visualisation pour la centralité de degré
plot_centrality_bars(top_actors, centrality_type='eigenvector')
# Out:
# Genre: Comedy
#   degree centrality:
#     Actor: nm0136797, Centrality: 0.0591
#     Actor: nm0005562, Centrality: 0.0538
#     Actor: nm0002071, Centrality: 0.0538
#   closeness centrality:
#     Actor: nm0005562, Centrality: 0.3980
#     Actor: nm0136797, Centrality: 0.3949
#     Actor: nm0177896, Centrality: 0.3912
#   betweenness centrality:
#     Actor: nm0451600, Centrality: 0.1072
#     Actor: nm1231899, Centrality: 0.0364
#     Actor: nm0177896, Centrality: 0.0339
#   eigenvector centrality:
#     Actor: nm0136797, Centrality: 0.1404
#     Actor: nm0002071, Centrality: 0.1256
#     Actor: nm1706767, Centrality: 0.1129
#   pagerank centrality:
#     Actor: nm0001191, Centrality: 0.0030
#     Actor: nm0136797, Centrality: 0.0028
#     Actor: nm0005562, Centrality: 0.0026
#
# Genre: Fantasy
#   degree centrality:
#     Actor: nm0842770, Centrality: 0.0356
#     Actor: nm0631490, Centrality: 0.0348
#     Actor: nm0000115, Centrality: 0.0333
#   closeness centrality:
#     Actor: nm0842770, Centrality: 0.3090
#     Actor: nm0631490, Centrality: 0.2949
#     Actor: nm0000457, Centrality: 0.2922
#   betweenness centrality:
#     Actor: nm0842770, Centrality: 0.0668
#     Actor: nm0000115, Centrality: 0.0483
#     Actor: nm0427964, Centrality: 0.0366
#   eigenvector centrality:
#     Actor: nm0631490, Centrality: 0.2354
#     Actor: nm0000136, Centrality: 0.2042
#     Actor: nm0574534, Centrality: 0.1530
#   pagerank centrality:
#     Actor: nm0000115, Centrality: 0.0039
#     Actor: nm0427964, Centrality: 0.0038
#     Actor: nm0000353, Centrality: 0.0036
#
# Genre: Romance
#   degree centrality:
#     Actor: nm0177896, Centrality: 0.0379
#     Actor: nm0000098, Centrality: 0.0342
#     Actor: nm0004754, Centrality: 0.0315
#   closeness centrality:
#     Actor: nm0177896, Centrality: 0.3426
#     Actor: nm0000285, Centrality: 0.3370
#     Actor: nm0004754, Centrality: 0.3343
#   betweenness centrality:
#     Actor: nm0451600, Centrality: 0.0889
#     Actor: nm0177896, Centrality: 0.0626
#     Actor: nm0461136, Centrality: 0.0270
#   eigenvector centrality:
#     Actor: nm0177896, Centrality: 0.1623
#     Actor: nm0004754, Centrality: 0.1439
#     Actor: nm0000098, Centrality: 0.1358
#   pagerank centrality:
#     Actor: nm0177896, Centrality: 0.0028
#     Actor: nm0000173, Centrality: 0.0026
#     Actor: nm0000379, Centrality: 0.0026
#
# Genre: Drama
#   degree centrality:
#     Actor: nm0000949, Centrality: 0.0458
#     Actor: nm0000288, Centrality: 0.0440
#     Actor: nm0000173, Centrality: 0.0440
#   closeness centrality:
#     Actor: nm0000173, Centrality: 0.3913
#     Actor: nm0000949, Centrality: 0.3895
#     Actor: nm0000288, Centrality: 0.3881
#   betweenness centrality:
#     Actor: nm0451600, Centrality: 0.0581
#     Actor: nm0451234, Centrality: 0.0327
#     Actor: nm0000821, Centrality: 0.0293
#   eigenvector centrality:
#     Actor: nm0000949, Centrality: 0.1123
#     Actor: nm0000288, Centrality: 0.1106
#     Actor: nm0424060, Centrality: 0.0993
#   pagerank centrality:
#     Actor: nm0000288, Centrality: 0.0021
#     Actor: nm0451321, Centrality: 0.0019
#     Actor: nm0000949, Centrality: 0.0018
#
# Genre: Music
#   degree centrality:
#     Actor: nm0004937, Centrality: 0.0405
#     Actor: nm0005024, Centrality: 0.0299
#     Actor: nm0000949, Centrality: 0.0299
#   closeness centrality:
#     Actor: nm0000152, Centrality: 0.0925
#     Actor: nm0000949, Centrality: 0.0883
#     Actor: nm0000288, Centrality: 0.0861
#   betweenness centrality:
#     Actor: nm0000152, Centrality: 0.0545
#     Actor: nm0000949, Centrality: 0.0465
#     Actor: nm0000288, Centrality: 0.0350
#   pagerank centrality:
#     Actor: nm0004937, Centrality: 0.0052
#     Actor: nm0000552, Centrality: 0.0051
#     Actor: nm0005024, Centrality: 0.0048
#
# Genre: Adventure
#   degree centrality:
#     Actor: nm0000168, Centrality: 0.0586
#     Actor: nm0425005, Centrality: 0.0499
#     Actor: nm0935653, Centrality: 0.0441
#   closeness centrality:
#     Actor: nm0000168, Centrality: 0.4001
#     Actor: nm0425005, Centrality: 0.3884
#     Actor: nm0935653, Centrality: 0.3871
#   betweenness centrality:
#     Actor: nm0000168, Centrality: 0.0413
#     Actor: nm0004715, Centrality: 0.0349
#     Actor: nm1126340, Centrality: 0.0304
#   eigenvector centrality:
#     Actor: nm0000168, Centrality: 0.1356
#     Actor: nm0935653, Centrality: 0.1286
#     Actor: nm0000949, Centrality: 0.1281
#   pagerank centrality:
#     Actor: nm0000168, Centrality: 0.0036
#     Actor: nm0262635, Centrality: 0.0030
#     Actor: nm0876138, Centrality: 0.0029
#
# Genre: Animation
#   degree centrality:
#     Actor: nm0004715, Centrality: 0.0834
#     Actor: nm0748973, Centrality: 0.0721
#     Actor: nm0000092, Centrality: 0.0594
#   closeness centrality:
#     Actor: nm0004715, Centrality: 0.3771
#     Actor: nm0748973, Centrality: 0.3641
#     Actor: nm0000092, Centrality: 0.3448
#   betweenness centrality:
#     Actor: nm0004715, Centrality: 0.1388
#     Actor: nm1126340, Centrality: 0.1045
#     Actor: nm0748973, Centrality: 0.0696
#   eigenvector centrality:
#     Actor: nm0004715, Centrality: 0.2507
#     Actor: nm0748973, Centrality: 0.1978
#     Actor: nm0736622, Centrality: 0.1626
#   pagerank centrality:
#     Actor: nm0876138, Centrality: 0.0085
#     Actor: nm0004715, Centrality: 0.0078
#     Actor: nm0000114, Centrality: 0.0051
#
# Genre: Action
#   degree centrality:
#     Actor: nm0000168, Centrality: 0.0610
#     Actor: nm0005458, Centrality: 0.0573
#     Actor: nm0425005, Centrality: 0.0555
#   closeness centrality:
#     Actor: nm0000168, Centrality: 0.4012
#     Actor: nm0425005, Centrality: 0.3969
#     Actor: nm0005458, Centrality: 0.3857
#   betweenness centrality:
#     Actor: nm0000168, Centrality: 0.0480
#     Actor: nm2138653, Centrality: 0.0453
#     Actor: nm0829032, Centrality: 0.0434
#   eigenvector centrality:
#     Actor: nm0000168, Centrality: 0.1441
#     Actor: nm0005458, Centrality: 0.1212
#     Actor: nm0425005, Centrality: 0.1205
#   pagerank centrality:
#     Actor: nm0000168, Centrality: 0.0034
#     Actor: nm0005458, Centrality: 0.0031
#     Actor: nm0262635, Centrality: 0.0030
#
# Genre: Biography
#   degree centrality:
#     Actor: nm0765597, Centrality: 0.0397
#     Actor: nm0000288, Centrality: 0.0397
#     Actor: nm1212722, Centrality: 0.0397
#   closeness centrality:
#     Actor: nm0000288, Centrality: 0.3198
#     Actor: nm1212722, Centrality: 0.3131
#     Actor: nm0765597, Centrality: 0.3096
#   betweenness centrality:
#     Actor: nm0000288, Centrality: 0.0409
#     Actor: nm0369854, Centrality: 0.0394
#     Actor: nm1212722, Centrality: 0.0380
#   eigenvector centrality:
#     Actor: nm0000288, Centrality: 0.2000
#     Actor: nm1212722, Centrality: 0.1824
#     Actor: nm0765597, Centrality: 0.1652
#   pagerank centrality:
#     Actor: nm0000288, Centrality: 0.0039
#     Actor: nm1212722, Centrality: 0.0034
#     Actor: nm0765597, Centrality: 0.0033
#
# Genre: Horror
#   degree centrality:
#     Actor: nm1631269, Centrality: 0.0228
#     Actor: nm5896355, Centrality: 0.0205
#     Actor: nm0005048, Centrality: 0.0190
#   closeness centrality:
#     Actor: nm1631269, Centrality: 0.2369
#     Actor: nm0252961, Centrality: 0.2355
#     Actor: nm5896355, Centrality: 0.2324
#   betweenness centrality:
#     Actor: nm1631269, Centrality: 0.0519
#     Actor: nm5896355, Centrality: 0.0453
#     Actor: nm0935541, Centrality: 0.0394
#   eigenvector centrality:
#     Actor: nm1631269, Centrality: 0.1512
#     Actor: nm0001424, Centrality: 0.1459
#     Actor: nm1544217, Centrality: 0.1367
#   pagerank centrality:
#     Actor: nm0068551, Centrality: 0.0035
#     Actor: nm0564215, Centrality: 0.0034
#     Actor: nm0933940, Centrality: 0.0031
#
# Genre: Mystery
#   degree centrality:
#     Actor: nm0000173, Centrality: 0.0268
#     Actor: nm0101005, Centrality: 0.0249
#     Actor: nm0933940, Centrality: 0.0249
#   closeness centrality:
#     Actor: nm0000173, Centrality: 0.2994
#     Actor: nm0000375, Centrality: 0.2960
#     Actor: nm0000174, Centrality: 0.2952
#   betweenness centrality:
#     Actor: nm0000173, Centrality: 0.0251
#     Actor: nm0001626, Centrality: 0.0213
#     Actor: nm0101005, Centrality: 0.0210
#   eigenvector centrality:
#     Actor: nm0000375, Centrality: 0.1336
#     Actor: nm0101005, Centrality: 0.1248
#     Actor: nm0001626, Centrality: 0.1241
#   pagerank centrality:
#     Actor: nm0933940, Centrality: 0.0035
#     Actor: nm0000158, Centrality: 0.0027
#     Actor: nm0267812, Centrality: 0.0026
#
# Genre: Thriller
#   degree centrality:
#     Actor: nm0005458, Centrality: 0.0621
#     Actor: nm0000553, Centrality: 0.0378
#     Actor: nm0000151, Centrality: 0.0352
#   closeness centrality:
#     Actor: nm0005458, Centrality: 0.3555
#     Actor: nm0000168, Centrality: 0.3283
#     Actor: nm0000198, Centrality: 0.3280
#   betweenness centrality:
#     Actor: nm0005458, Centrality: 0.0819
#     Actor: nm2138653, Centrality: 0.0714
#     Actor: nm1017633, Centrality: 0.0624
#   eigenvector centrality:
#     Actor: nm0005458, Centrality: 0.2458
#     Actor: nm0000246, Centrality: 0.1275
#     Actor: nm0000151, Centrality: 0.1157
#   pagerank centrality:
#     Actor: nm0005458, Centrality: 0.0054
#     Actor: nm0000553, Centrality: 0.0030
#     Actor: nm0474774, Centrality: 0.0028
#
# Genre: Sci-Fi
#   degree centrality:
#     Actor: nm0424060, Centrality: 0.0483
#     Actor: nm0000168, Centrality: 0.0474
#     Actor: nm0262635, Centrality: 0.0440
#   closeness centrality:
#     Actor: nm0262635, Centrality: 0.3351
#     Actor: nm0000168, Centrality: 0.3329
#     Actor: nm0429363, Centrality: 0.3248
#   betweenness centrality:
#     Actor: nm0000168, Centrality: 0.0488
#     Actor: nm0429363, Centrality: 0.0420
#     Actor: nm0424060, Centrality: 0.0380
#   eigenvector centrality:
#     Actor: nm0262635, Centrality: 0.2599
#     Actor: nm0424060, Centrality: 0.2565
#     Actor: nm0000375, Centrality: 0.2238
#   pagerank centrality:
#     Actor: nm0424060, Centrality: 0.0079
#     Actor: nm0262635, Centrality: 0.0066
#     Actor: nm0000375, Centrality: 0.0056
#
# Genre: Crime
#   degree centrality:
#     Actor: nm0005458, Centrality: 0.0478
#     Actor: nm0000168, Centrality: 0.0405
#     Actor: nm0268199, Centrality: 0.0401
#   closeness centrality:
#     Actor: nm0005458, Centrality: 0.3563
#     Actor: nm0268199, Centrality: 0.3518
#     Actor: nm0000242, Centrality: 0.3454
#   betweenness centrality:
#     Actor: nm1231899, Centrality: 0.0720
#     Actor: nm0425005, Centrality: 0.0557
#     Actor: nm0451234, Centrality: 0.0475
#   eigenvector centrality:
#     Actor: nm0005458, Centrality: 0.1440
#     Actor: nm0268199, Centrality: 0.1391
#     Actor: nm0000168, Centrality: 0.1216
#   pagerank centrality:
#     Actor: nm0005458, Centrality: 0.0035
#     Actor: nm0474774, Centrality: 0.0030
#     Actor: nm0268199, Centrality: 0.0027
#
# Genre: Family
#   degree centrality:
#     Actor: nm0002006, Centrality: 0.0400
#     Actor: nm0004266, Centrality: 0.0362
#     Actor: nm0000136, Centrality: 0.0362
#   closeness centrality:
#     Actor: nm0000245, Centrality: 0.2751
#     Actor: nm0005562, Centrality: 0.2736
#     Actor: nm0002006, Centrality: 0.2730
#   betweenness centrality:
#     Actor: nm0002006, Centrality: 0.0921
#     Actor: nm0000151, Centrality: 0.0681
#     Actor: nm0000245, Centrality: 0.0563
#   eigenvector centrality:
#     Actor: nm0914612, Centrality: 0.2405
#     Actor: nm0705356, Centrality: 0.2197
#     Actor: nm0342488, Centrality: 0.2197
#   pagerank centrality:
#     Actor: nm0914612, Centrality: 0.0045
#     Actor: nm0000741, Centrality: 0.0045
#     Actor: nm0000151, Centrality: 0.0043
#
# Genre: Sport
#   degree centrality:
#     Actor: nm0000226, Centrality: 0.0583
#     Actor: nm0004715, Centrality: 0.0583
#     Actor: nm0002071, Centrality: 0.0538
#   closeness centrality:
#     Actor: nm0000671, Centrality: 0.1597
#     Actor: nm0005405, Centrality: 0.1506
#     Actor: nm0688132, Centrality: 0.1499
#   betweenness centrality:
#     Actor: nm0000671, Centrality: 0.2047
#     Actor: nm0553269, Centrality: 0.0965
#     Actor: nm0379596, Centrality: 0.0924
#   eigenvector centrality:
#     Actor: nm0002071, Centrality: 0.3790
#     Actor: nm0004715, Centrality: 0.3181
#     Actor: nm0725200, Centrality: 0.2960
#   pagerank centrality:
#     Actor: nm0000226, Centrality: 0.0083
#     Actor: nm0004715, Centrality: 0.0067
#     Actor: nm0000230, Centrality: 0.0066
#
# Genre: War
#   degree centrality:
#     Actor: nm0000093, Centrality: 0.0651
#     Actor: nm0000123, Centrality: 0.0651
#     Actor: nm0001602, Centrality: 0.0498
#   closeness centrality:
#     Actor: nm1310016, Centrality: 0.0932
#     Actor: nm0001602, Centrality: 0.0907
#     Actor: nm0350453, Centrality: 0.0899
#   betweenness centrality:
#     Actor: nm1310016, Centrality: 0.0381
#     Actor: nm0350453, Centrality: 0.0371
#     Actor: nm0001602, Centrality: 0.0363
#   eigenvector centrality:
#     Actor: nm0000123, Centrality: 0.3895
#     Actor: nm0000191, Centrality: 0.2680
#     Actor: nm0000228, Centrality: 0.2680
#   pagerank centrality:
#     Actor: nm0000093, Centrality: 0.0094
#     Actor: nm0401264, Centrality: 0.0072
#     Actor: nm0001602, Centrality: 0.0070
#
# Genre: History
#   degree centrality:
#     Actor: nm0929489, Centrality: 0.0604
#     Actor: nm0051509, Centrality: 0.0493
#     Actor: nm0835016, Centrality: 0.0477
#   closeness centrality:
#     Actor: nm0835016, Centrality: 0.2831
#     Actor: nm0001354, Centrality: 0.2789
#     Actor: nm0001691, Centrality: 0.2713
#   betweenness centrality:
#     Actor: nm1670029, Centrality: 0.1172
#     Actor: nm0706787, Centrality: 0.1148
#     Actor: nm0835016, Centrality: 0.1039
#   eigenvector centrality:
#     Actor: nm0001354, Centrality: 0.2333
#     Actor: nm0835016, Centrality: 0.2293
#     Actor: nm0164809, Centrality: 0.2273
#   pagerank centrality:
#     Actor: nm0929489, Centrality: 0.0065
#     Actor: nm0429363, Centrality: 0.0052
#     Actor: nm0051509, Centrality: 0.0050
#
# Genre: Musical
#   degree centrality:
#     Actor: nm0451321, Centrality: 0.1275
#     Actor: nm0611552, Centrality: 0.0931
#     Actor: nm0000821, Centrality: 0.0833
#   closeness centrality:
#     Actor: nm0000658, Centrality: 0.1491
#     Actor: nm1086543, Centrality: 0.1374
#     Actor: nm0002043, Centrality: 0.1363
#   betweenness centrality:
#     Actor: nm0000658, Centrality: 0.0566
#     Actor: nm0000173, Centrality: 0.0466
#     Actor: nm1086543, Centrality: 0.0459
#   eigenvector centrality:
#     Actor: nm0451321, Centrality: 0.3768
#     Actor: nm0611552, Centrality: 0.3168
#     Actor: nm0000821, Centrality: 0.2945
#   pagerank centrality:
#     Actor: nm0451321, Centrality: 0.0151
#     Actor: nm0000173, Centrality: 0.0113
#     Actor: nm1086543, Centrality: 0.0107
#
# Genre: Western
#   degree centrality:
#     Actor: nm0763928, Centrality: 0.0891
#     Actor: nm0001664, Centrality: 0.0792
#     Actor: nm3718007, Centrality: 0.0693
#   closeness centrality:
#     Actor: nm0763928, Centrality: 0.0891
#     Actor: nm3718007, Centrality: 0.0693
#     Actor: nm0000234, Centrality: 0.0693
#   betweenness centrality:
#     Actor: nm0763928, Centrality: 0.0040
#     Actor: nm3718007, Centrality: 0.0024
#     Actor: nm0378660, Centrality: 0.0000
#   eigenvector centrality:
#     Actor: nm0000234, Centrality: 0.3536
#     Actor: nm0000553, Centrality: 0.3536
#     Actor: nm1086543, Centrality: 0.3536
#   pagerank centrality:
#     Actor: nm0763928, Centrality: 0.0167
#     Actor: nm3718007, Centrality: 0.0164
#     Actor: nm0001664, Centrality: 0.0154
#
# Genre: Documentary
#   degree centrality:
#     Actor: nm0000151, Centrality: 1.0000
#     Actor: nm0001960, Centrality: 1.0000
#     Actor: nm0075650, Centrality: 1.0000
#   closeness centrality:
#     Actor: nm0000151, Centrality: 0.7500
#     Actor: nm0001960, Centrality: 0.7500
#     Actor: nm0075650, Centrality: 0.7500
#   betweenness centrality:
#     Actor: nm0000151, Centrality: 0.0000
#     Actor: nm0001960, Centrality: 0.0000
#     Actor: nm0075650, Centrality: 0.0000
#   eigenvector centrality:
#     Actor: nm0000151, Centrality: 0.3780
#     Actor: nm0001960, Centrality: 0.3780
#     Actor: nm0075650, Centrality: 0.3780
#   pagerank centrality:
#     Actor: nm0000335, Centrality: 0.1312
#     Actor: nm0000151, Centrality: 0.1111
#     Actor: nm0001960, Centrality: 0.1111

# %% [markdown]
# ## Calculer la correlation entre la centralite et le succes

# %%
# Corrélation entre centralité et succès par genre
def analyze_centrality_success_by_genre(movies, centralities_by_genre):
    correlations = {}
    
    for genre, centralities in centralities_by_genre.items():
        genre_movies = movies[movies['genres'].apply(lambda x: genre in x)]
        for centrality_type, centrality_scores in centralities.items():
            actor_scores = []
            movie_ratings = []
            
            for actor, score in centrality_scores.items():
                actor_movies = genre_movies[genre_movies['tconst'].isin(actors[actors['nconst'] == actor]['tconst'])]
                if not actor_movies.empty:
                    average_rating = actor_movies['averageRating'].mean()
                    actor_scores.append(score)
                    movie_ratings.append(average_rating)
            
            if actor_scores and movie_ratings:
                correlation = np.corrcoef(actor_scores, movie_ratings)[0, 1]
                if genre not in correlations:
                    correlations[genre] = {}
                correlations[genre][centrality_type] = correlation
    
    return correlations

correlations_by_genre = analyze_centrality_success_by_genre(movies, centrality_measures)
# Out:
# /home/victor/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/victor/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]

# %% [markdown]
# ### Heatmap

# %%
# Convertir les corrélations en DataFrame pour la heatmap
correlations_df = pd.DataFrame(correlations_by_genre).T
correlations_df = correlations_df.drop('Documentary')

# Création de la heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlations_df, annot=True, cmap='coolwarm', center=0)
plt.title('Correlation Between Centrality and Movie Success by Genre')
plt.ylabel('Genre')
plt.show()
